# %% [markdown]
# # Конспект книги "Python для сложных задач" Дж. Вандер Плас

# %% [markdown]
# # Глава 4.Визуализация с помощью библиотеки Matplotlib

# %% [markdown]
# ## Общие советы по библиотеке

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# В Matplotlib можно устанавливать различные уже встроенные стили графиков

# %%
plt.style.use('classic')

# %% [markdown]
# Синтаксис отображения графиков зависит от среды, где выполняется код: изнутри сценария, в командной оболочке IPython или в блокноте IPython. В первой необходимо использовать команду plt.show(), в остальных графики автоматически выводятся в оболочках

# %% [markdown]
# Оболочка IPython(и Jupyter notebook) будет отлично работать с библиотекойmMatplotlib, если перевести ее в режим Matplotlib

# %%
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# После любая команда plot приведет к открытию окна графика с возможностью выполнения дальнейших команд для его изменения. Некоторые изменения (например, модификация свойств уже нарисованных линий) не будут отрисовываться автоматически. Чтобы добиться этого, воспользуйтесь командой plt.draw(). Выполнять команду plt.show() в режиме Matplotlib не обязательно

# %% [markdown]
# Можно использовать 2 режима вывода: динамические графики и статичесвкие

# %%
# интерактивные графики
# %matplotlib notebook
# статические графики
# %matplotlib inline

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %% [markdown]
# Полученные рисунки можно сохранять с помощью команды savefig()

# %%
#fig.savefig('my_figure.png')

# %% [markdown]
# Вывести список поддерживаемых форматов файлов для вашей системы можно с помощью следующего метода объекта canvas рисунка

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ### Два интерфейса

# %% [markdown]
# В библиотеке реализована два способа взаимодействия - MATLAB-подобный и объектно-ориентированный

# %% [markdown]
# В MatLab подобном интерфейсе сначала создаётся "холст"(фигура) для графика, а затем путём переключения между установленными частями фигуры можно выводить на текущий выбранный график. Т.е. данный интерфейс запоминает, в какой части вы находитесь и рисует только там

# %%
plt.figure() # Создаем рисунок для графика
# Создаем первую из двух областей графика и задаем текущую ось
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# Создаем вторую область и задаем текущую ось
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %% [markdown]
# В объектно-ориентированном подходе интерфейс функций рисования является методами явным образом определяемых объектов Figure и Axes

# %%
# Сначала создаем сетку графиков
# ax будет массивом из двух объектов Axes
fig, ax = plt.subplots(2)
# Вызываем метод plot() соответствующего объекта
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# ## Простые линейные графики

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')

# %%
fig = plt.figure()
ax = plt.axes()

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# Рисунок - экземпляр класса plt.Figure - контейнер, содержащий все объекты, представляющие систему координат, графику, текст и метки
# Система координат - экземпля класса plt.Axes - ограничивающий прямоугольник с делениями

# %% [markdown]
# ax.plot применяется для построения графика данных

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x))

# %% [markdown]
# ### Цвета и стили линий

# %% [markdown]
# Цвет графика задаётся аргументом color

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(x, np.sin(x - 0), color='blue') # Задаем цвет по названию
ax.plot(x, np.sin(x - 1), color='g') # Краткий код цвета (rgbcmyk)
ax.plot(x, np.sin(x - 2), color='0.75') # Шкала оттенков серого цвета, значения в диапазоне от 0 до 1
ax.plot(x, np.sin(x - 3), color='#FFDD44') # 16-ричный код (RRGGBB от 00 до FF)
ax.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # Кортеж RGB, значения 0 и 1
ax.plot(x, np.sin(x - 5), color='chartreuse'); # Поддерживаются все названия цветов HTML

# %%
plt.plot(x, np.sin(x - 0), color='blue') # Задаем цвет по названию
plt.plot(x, np.sin(x - 1), color='g') # Краткий код цвета (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Шкала оттенков серого цвета, значения в диапазоне от 0 до 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # 16-ричный код (RRGGBB от 00 до FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # Кортеж RGB, значения 0 и 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # Поддерживаются все названия цветов HTML

# %% [markdown]
# Стиль линий настраивается с помощью ключевого слова linestyle

# %%
plt.plot(x, x - 1, linestyle='-') # сплошная линия 'solid'
plt.plot(x, x - 2, linestyle='--') #штриховая линия 'dashed'
plt.plot(x, x - 3, linestyle=':') # пунктирная 'dotted'
plt.plot(x, x - 4, linestyle='-.') # штрихпунктирная 'dashdot'

# %% [markdown]
# Можно задавать стиль и цвет одним аргументом

# %%
plt.plot(x, x + 0, '-g') # сплошная линия зеленого цвета
plt.plot(x, x + 1, '--c') # штриховая линия голубого цвета
plt.plot(x, x + 2, '-.k') # штрихпунктирная линия черного цвета
plt.plot(x, x + 3, ':r'); # пунктирная линия красного цвета

# %% [markdown]
# Пределы осей координат настраивают методы plt.xlim и plt.ylim

# %%
plt.plot(x, np.sin(x))

plt.xlim(0, np.pi * 3)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %% [markdown]
# Можно задавать пределы в обратном порядке, тогда оси инвертируются

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(x, np.sin(x))
ax.set_xlim(0, np.pi * 3)
ax.set_ylim(2, -1)
# Out:
# (2.0, -1.0)

# %% [markdown]
# Есть метод plt.axis, которому передаётся список  [xmin, xmax, ymin, ymax]

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
# Out:
# (np.float64(-1.0), np.float64(11.0), np.float64(-1.5), np.float64(1.5))

# %% [markdown]
# plt.axis умеет подгонять границы к текущему графику

# %%
fig = plt.figure()
ax = plt.axes()

ax.plot(x, np.sin(x))
ax.axis('tight')
# Out:
# (np.float64(0.0),
#  np.float64(10.0),
#  np.float64(-0.9993845576124357),
#  np.float64(0.9996923408861117))

# %% [markdown]
# Или можно выровнять соотношение сторон графика

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (np.float64(0.0), np.float64(10.0), np.float64(-1.0), np.float64(1.0))

# %% [markdown]
# ### Метки на графиках

# %%
plt.plot(x, np.sin(x))

plt.title("Синусоидальная кривая") ## иногда нужно использовать title, зависит от используемого стиля
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# Можно создавать легенду графика

# %%
fig = plt.figure
ax = plt.axes()

ax.plot(x, np.sin(x), '-r', label='sin(x)')
ax.plot(x, np.cos(x), ':b', label='cos(x)')
ax.axis('equal')

ax.set_title('Graphics')
ax.set_xlabel('x')
ax.set_ylabel('y')

ax.legend(labelcolor='black')

# %%
fig = plt.figure
ax = plt.axes()

ax.plot(x, np.sin(x), '-r', label='sin(x)')
ax.plot(x, np.cos(x), ':b', label='cos(x)')

ax.set(
    xlim=(0, 10),
    ylim=(-2, 2),
    xlabel='x',
    ylabel='y',
    title='Plot'
)
# Out:
# [(0.0, 10.0),
#  (-2.0, 2.0),
#  Text(0.5, 0, 'x'),
#  Text(0, 0.5, 'y'),
#  Text(0.5, 1.0, 'Plot')]

# %% [markdown]
# ## Простые диаграммы рассеяния

# %% [markdown]
# ### Построение диаграмм рассеяния с помощью функции plot

# %% [markdown]
# Диаграммы рассеивания - набор несоединённых точек на плоскости. Для построения диаграммы рассеивания достаточно указать макер, которым будут обозначаться точки вместо обозначнения стиля линии

# %%
for marker in ['o', '.', ',', 'x', '+']:
    plt.plot(
        np.random.rand(10), 
        np.random.rand(10), 
        marker,
        label=f"marker={marker}")
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %% [markdown]
# Если совместить обозначние маркера и стиля линии, то можно получить график с выделенными точками, соединёнными прямыми линиями

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, np.sin(x), 'o-')

# %%
for marker in ['o', '.', ',', 'x', '+']:
    plt.plot(
        np.random.rand(10), 
        np.random.rand(10), 
        marker + '-',
        label=f"marker={marker}"
        )
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %% [markdown]
# С помощью дополнительных ключевых аргументов функции plt.plot можно задавать множество свойств линий и маркеров

# %%
plt.plot(x, y, '-h', color='magenta', markersize=12, linewidth=6, markerfacecolor='grey', 
        markeredgecolor='blue', markeredgewidth=3)

# %% [markdown]
# ### Построение диаграмм рассеяния с помощью функции plt.scatter

# %%
plt.scatter(x, y, marker='o')

# %% [markdown]
# Основное различие между функциями plt.scatter и plt.plot состоит в том, что с помощью первой можно создавать диаграммы рассеяния с индивидуально задаваемыми (или выбираемыми в соответствии с данными) свойствами каждой точки (размер, цвет заливки, цвет рамки и т. д.)

# %% [markdown]
# alpha позволяет настроить уровень прозрачности

# %%
rng = np.random
x = rng.randn(100)
y = rng.randn(100)
colors = rng.randn(100)
sizes = 1000 * rng.randn(100)

# %%
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar()
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# scatter позволяет настраивать каждую точку в отдельности, поэтому на больших данных она может работать гораздо дольше чем plot

# %% [markdown]
# ## Визуализация погрешностей

# %% [markdown]
# Простые планки погрешностей можно создать с помощью вызова всего одной функции

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * rng.rand(50)

# %%
plt.errorbar(x, y, yerr=dy, fmt=':b')
plt.plot(x, np.sin(x))

# %% [markdown]
# fmt - это код форматирования, управлябщий внешним видом линий и точек (считай цвета и стили обычного plot)

# %% [markdown]
# Функция имеет множество настроек

# %%
plt.errorbar(x, y, yerr=dy, fmt='.', color='black',
            ecolor='lightgrey', elinewidth=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Графики плотности и контурные графики

# %% [markdown]
# ### Визуализация трехмерной функции

# %%
def f(x, y):
    return np.sin(x) + np.log2(x * y + 1) - 8

# %% [markdown]
# Создать контурный график можно с помощью функции plt.contour. У нее имеется три аргумента: координатная сетка значений x, координатная сетка значений y и координатная сетка значений z. Значения x и y представлены точками на графике, а значения z будут представлены контурами уровней

# %%
x = np.linspace(0, 100, 1000)
y = np.linspace(0, 100, 1000)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black')

# %%
plt.contour(X, Y, Z, 10, cmap='seismic')

# %% [markdown]
# Чтобы между линиями не было промежутков, можно использовать plt.contourf

# %%
plt.contourf(X, Y, Z, 20, cmap='seismic')
plt.colorbar()

# %% [markdown]
# plt.imshow() позволяет обойти проблему с тем, что на изображение выше есть четкий переход между цветами, при этом производительность не сильно упадёт

# %%
plt.imshow(Z, extent=[0, 100, 0, 100], origin='lower', cmap='seismic')
plt.colorbar()
plt.axis('image')
# Out:
# (np.float64(0.0), np.float64(100.0), np.float64(0.0), np.float64(100.0))

# %%
fig, ax = plt.figure(), plt.axes()

contours = ax.contour(X, Y, Z, 10, cmap='seismic')
ax.clabel(contours, inline=True)

im = ax.imshow(Z, extent=[0, 100, 0, 100], cmap='seismic', alpha=0.5)
fig.colorbar(im)

# %% [markdown]
# ## Гистограммы, разбиения по интервалам и плотность

# %%
data = np.random.randn(1000000)

# %%
plt.hist(data)
# Out:
# (array([1.12000e+02, 2.99500e+03, 3.44510e+04, 1.69019e+05, 3.50131e+05,
#         3.08528e+05, 1.15565e+05, 1.80030e+04, 1.15400e+03, 4.20000e+01]),
#  array([-4.66796538, -3.70579266, -2.74361995, -1.78144724, -0.81927453,
#          0.14289818,  1.10507089,  2.0672436 ,  3.02941632,  3.99158903,
#          4.95376174]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=30, alpha=0.5, density=True, histtype='stepfilled', color='steelblue', edgecolor='none');

# %%
import scipy.stats as stats

# %%
x1 = np.random.randn(10_000)
x2 = stats.binom(n=100, p=0.3).rvs(10_000)
x3 = stats.expon(scale=3).rvs(10_000) - 50

# %%
fig, ax = plt.figure(), plt.axes()

kwargs = dict(bins=50, alpha=0.3, density=True, histtype='stepfilled')

ax.hist(x1, **kwargs)
ax.hist(x2, **kwargs)
ax.hist(x3, **kwargs);

# %% [markdown]
# ### Двумерные гистограммы и разбиения по интервалам

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 1_000_000).T

# %%
plt.hist2d(x, y, bins=100, cmap='seismic')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %% [markdown]
# Есть гистограммы с гексагональным разбиением по интервалам

# %%
plt.hexbin(x, y, gridsize=50, cmap='seismic')
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# ## Пользовательские настройки легенд на графиках

# %%
x = np.linspace(0, 10, 101)

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Синус')
ax.plot(x, np.cos(x), '--r', label='Косинус')
ax.axis('equal')
leg = ax.legend()

# %% [markdown]
# Есть множество пользовательских настроек легенды

# %% [markdown]
# loc настраивает положение легенды
# frameon настраивает рамки легенды

# %%
ax.legend(loc='lower left', frameon=False)
fig

# %% [markdown]
# ncol настраивает количество столбцов в легенде

# %%
ax.legend(loc='lower center', ncol=2)
fig

# %% [markdown]
# fancybox позволяет использовать для легенды скруглённую прямоугольную рамку
# framealpha настраивает прозрачность
# borderpad настраивает размер поле возле текста
# shadow настраивает тень от легенды

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# По умолчанию legend() отображает легенды только помеченных label элементов, однако можно передать аргумент lines[], указывающий, что именно нужно отобразить

# %%
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))

fig, ax = plt.subplots()

lines = ax.plot(x, y) # 4 линии
ax.legend(lines[:2], ['Первый', 'Второй'])

# %% [markdown]
# Или можно сделать так

# %%
fig, ax = plt.subplots()

ax.plot(x, y[:, 0], label='Первый')
ax.plot(x, y[:, 1], label='Второй')
ax.plot(x, y[:, 2:])
ax.legend(framealpha=1, frameon=True)
